# %%
import pandas as pd

# %%
df_transaction = pd.read_excel("online_retail_II.xlsx",sheet_name="Year 2009-2010")

# %%
df_transaction.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df_transaction.dropna(inplace=True)

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417534 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      417534 non-null  object
#  1   StockCode    417534 non-null  object
#  2   Description  417534 non-null  object
#  3   Quantity     417534 non-null  int64
#  4   InvoiceDate  417534 non-null  datetime64[ns]
#  5   Price        417534 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      417534 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 28.7+ MB

# %%
df_recency = df_transaction.groupby(by='Customer ID',as_index=False)['InvoiceDate'].max()

# %%
df_recency.head()
# Out:
#    Customer ID         InvoiceDate
# 0      12346.0 2010-10-04 16:33:00
# 1      12347.0 2010-12-07 14:57:00
# 2      12348.0 2010-09-27 14:59:00
# 3      12349.0 2010-10-28 08:23:00
# 4      12351.0 2010-11-29 15:23:00

# %%
df_recency.columns = ['Customer ID','LastInvoiceDate']

# %%
df_recency.head()
# Out:
#    Customer ID     LastInvoiceDate
# 0      12346.0 2010-10-04 16:33:00
# 1      12347.0 2010-12-07 14:57:00
# 2      12348.0 2010-09-27 14:59:00
# 3      12349.0 2010-10-28 08:23:00
# 4      12351.0 2010-11-29 15:23:00

# %%
recent_date = df_recency['LastInvoiceDate'].max()

# %%
recent_date
# Out:
# Timestamp('2010-12-09 20:01:00')

# %%
df_recency['Recency'] = df_recency['LastInvoiceDate'].apply(lambda lid:(recent_date - lid).days)

# %%
df_recency.head()
# Out:
#    Customer ID     LastInvoiceDate  Recency
# 0      12346.0 2010-10-04 16:33:00       66
# 1      12347.0 2010-12-07 14:57:00        2
# 2      12348.0 2010-09-27 14:59:00       73
# 3      12349.0 2010-10-28 08:23:00       42
# 4      12351.0 2010-11-29 15:23:00       10

# %%
df_frequency = df_transaction.groupby(by='Customer ID',as_index=False)["InvoiceDate"].count()

# %%
df_frequency.columns = ['Customer ID','Frequency']

# %%
df_frequency.head()
# Out:
#    Customer ID  Frequency
# 0      12346.0         46
# 1      12347.0         71
# 2      12348.0         20
# 3      12349.0        107
# 4      12351.0         21

# %%
df_transaction['Total_value'] = df_transaction.Quantity * df_transaction.Price

# %%
df_transaction.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Total_value
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom         83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom        100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom         30.0

# %%
df_monetory = df_transaction.groupby(by='Customer ID',as_index=False)["Total_value"].sum()

# %%
df_monetory.head()
# Out:
#    Customer ID  Total_value
# 0      12346.0       -64.68
# 1      12347.0      1323.32
# 2      12348.0       222.16
# 3      12349.0      2646.99
# 4      12351.0       300.93

# %%
df_monetory.columns = ['Customer ID','Monetory']

# %%
df_monetory.head()
# Out:
#    Customer ID  Monetory
# 0      12346.0    -64.68
# 1      12347.0   1323.32
# 2      12348.0    222.16
# 3      12349.0   2646.99
# 4      12351.0    300.93

# %% [markdown]
# ##### Merge three dataframes (Recency, Frequency, Monetory)

# %%
df_merge = df_frequency.merge(df_recency, on = 'Customer ID')

# %%
df_merge.drop(['LastInvoiceDate'],axis=1,inplace=True)

# %%
df_merge.head()
# Out:
#    Customer ID  Frequency  Recency
# 0      12346.0         46       66
# 1      12347.0         71        2
# 2      12348.0         20       73
# 3      12349.0        107       42
# 4      12351.0         21       10

# %%
rfm_df = df_merge.merge(df_monetory,on = 'Customer ID')

# %%
rfm_df.head()
# Out:
#    Customer ID  Frequency  Recency  Monetory
# 0      12346.0         46       66    -64.68
# 1      12347.0         71        2   1323.32
# 2      12348.0         20       73    222.16
# 3      12349.0        107       42   2646.99
# 4      12351.0         21       10    300.93

# %%
rfm_df['freq_rank'] = rfm_df['Frequency'].rank(ascending = True)
rfm_df['rec_rank'] =  rfm_df['Recency'].rank(ascending = False)
rfm_df['mon_rank'] = rfm_df['Monetory'].rank(ascending=True)

# %%
rfm_df.head()
# Out:
#    Customer ID  Frequency  Recency  Monetory  freq_rank  rec_rank  mon_rank
# 0      12346.0         46       66    -64.68     2262.5    1792.0      53.0
# 1      12347.0         71        2   1323.32     2816.5    4126.5    3044.0
# 2      12348.0         20       73    222.16     1221.0    1651.5     838.0
# 3      12349.0        107       42   2646.99     3331.5    2421.0    3746.0
# 4      12351.0         21       10    300.93     1277.5    3645.0    1159.0

# %%
rfm_df['freq_rank_norm'] = (rfm_df['freq_rank']/rfm_df['freq_rank'].max())*100
rfm_df['rec_rank_norm'] = (rfm_df['rec_rank']/rfm_df['rec_rank'].max())*100
rfm_df['mon_rank_norm'] = (rfm_df['mon_rank']/rfm_df['mon_rank'].max())*100

# %%
rfm_df.head()
# Out:
#    Customer ID  Frequency  Recency  Monetory  freq_rank  rec_rank  mon_rank  \
# 0      12346.0         46       66    -64.68     2262.5    1792.0      53.0
# 1      12347.0         71        2   1323.32     2816.5    4126.5    3044.0
# 2      12348.0         20       73    222.16     1221.0    1651.5     838.0
# 3      12349.0        107       42   2646.99     3331.5    2421.0    3746.0
# 4      12351.0         21       10    300.93     1277.5    3645.0    1159.0
#
#    freq_rank_norm  rec_rank_norm  mon_rank_norm
# 0       51.619895      41.457490       1.209217
# 1       64.259640      95.465587      69.450148
# 2       27.857632      38.207056      19.119325
# 3       76.009582      56.009254      85.466575
# 4       29.146703      84.326200      26.443076

# %%
rfm_df.drop(['freq_rank','rec_rank','mon_rank'],axis=1, inplace=True)

# %%
rfm_df['rfm_score'] = rfm_df['freq_rank_norm']*0.28 + rfm_df['rec_rank_norm']*0.15 + rfm_df['mon_rank_norm']*0.57

# %%
rfm_df.head()
# Out:
#    Customer ID  Frequency  Recency  Monetory  freq_rank_norm  rec_rank_norm  \
# 0      12346.0         46       66    -64.68       51.619895      41.457490
# 1      12347.0         71        2   1323.32       64.259640      95.465587
# 2      12348.0         20       73    222.16       27.857632      38.207056
# 3      12349.0        107       42   2646.99       76.009582      56.009254
# 4      12351.0         21       10    300.93       29.146703      84.326200
#
#    mon_rank_norm  rfm_score
# 0       1.209217  21.361448
# 1      69.450148  71.899122
# 2      19.119325  24.429210
# 3      85.466575  78.400019
# 4      26.443076  35.882560

# %% [markdown]
# ### RFM Thresholds
# ###### High value customers - rfm_score > 0.7
# ###### Medium value customers - rfm_score < = 0.7 and >0.25
# ###### Low value customers - rfm_score <=  0.25

# %%
rfm_df.head()
# Out:
#    Customer ID  Frequency  Recency  Monetory  freq_rank_norm  rec_rank_norm  \
# 0      12346.0         46       66    -64.68       51.619895      41.457490
# 1      12347.0         71        2   1323.32       64.259640      95.465587
# 2      12348.0         20       73    222.16       27.857632      38.207056
# 3      12349.0        107       42   2646.99       76.009582      56.009254
# 4      12351.0         21       10    300.93       29.146703      84.326200
#
#    mon_rank_norm  rfm_score
# 0       1.209217  21.361448
# 1      69.450148  71.899122
# 2      19.119325  24.429210
# 3      85.466575  78.400019
# 4      26.443076  35.882560

# %%
rfm_df.loc[rfm_df['rfm_score']>75,'Class'] = 'High Value'

# %%
rfm_df.loc[rfm_df['rfm_score']<=25,'Class'] = 'Low Value'

# %%
rfm_df.loc[(rfm_df['rfm_score']>25) & (rfm_df['rfm_score'] <=75),'Class'] = 'Medium Value'

# %%
rfm_df.head()
# Out:
#    Customer ID  Frequency  Recency  Monetory  freq_rank_norm  rec_rank_norm  \
# 0      12346.0         46       66    -64.68       51.619895      41.457490
# 1      12347.0         71        2   1323.32       64.259640      95.465587
# 2      12348.0         20       73    222.16       27.857632      38.207056
# 3      12349.0        107       42   2646.99       76.009582      56.009254
# 4      12351.0         21       10    300.93       29.146703      84.326200
#
#    mon_rank_norm  rfm_score         Class
# 0       1.209217  21.361448     Low Value
# 1      69.450148  71.899122  Medium Value
# 2      19.119325  24.429210     Low Value
# 3      85.466575  78.400019    High Value
# 4      26.443076  35.882560  Medium Value
